# %%
import pickle
import numpy as np
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
import csv
import collections
import random

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
    
def get_vocab_and_vectors(year):
    with open(f"sgns/{year}-vocab.pkl", 'rb') as f:
        vocab = pickle.load(f)
    vectors = np.load(f"sgns/{year}-w.npy")
    return vocab, vectors

vocab, vectors = get_vocab_and_vectors(1950)

def cosine(x, y):
    return np.dot(x,y)/(np.linalg.norm(x)*np.linalg.norm(y))

# def find_nearest_neighbors(vector, all_vecs):
#     return np.argsort(np.dot(all_vecs, -vector))


NOT_FOUND = "not_found"
ZERO_VECTOR = "zero_vector"

def vector_lookup(word, vector_map):
    if word not in vector_map:
        return None, NOT_FOUND
    else:
        maybe_vec = vector_map[word]
        if not sum(maybe_vec):
            return None, ZERO_VECTOR
        else:
            return maybe_vec, None
        
def build_map(year):
    vocab, vectors = get_vocab_and_vectors(year)
    return {token:vector for token, vector in zip(vocab, vectors)}

DECADES = [f'19{decade_digit}0' for decade_digit in range(10)]
DIMENSIONS = ['Affluence', 'Cultivation', 'Education', 'Employment', 'Gender', 'Morality', 'Race', 'Status']
COLOR_DICT = {a:b for a,b in zip(DIMENSIONS, sns.color_palette("Set2"))}

vector_maps = {}
for decade in DECADES:
    vector_maps[decade] = build_map(decade)

# %%
pair_list = collections.defaultdict(list)

with open('word-pairs.tsv', 'r') as f:
    reader = csv.DictReader(f, delimiter='\t')
    for row in reader:
        pair_list[row['Category']].append((row['Positive'], row['Negative']))

# %%
import pandas as pd

plt.figure(figsize=(6, 10), dpi=200)

def get_vector(word, decade):
    return vector_lookup(word, vector_maps[decade])[0]

for category, pairs in pair_list.items():
    if not category == "Status":
        continue
    df_dicts = []
    for pos, neg in pairs:
        row = {"pair": f"{pos},{neg}",}
        for decade, decade_vecs in vector_maps.items():
            maybe_pos = get_vector(pos, decade)
            maybe_neg = get_vector(neg, decade)
            if maybe_pos is not None and maybe_neg is not None:
                result = 1
            else:
                result = 0
            row[decade] = result
        df_dicts.append(row)
    df = pd.DataFrame.from_dict(df_dicts)
    ax = sns.heatmap(df.set_index('pair'), xticklabels=True, yticklabels=True)

# %%
affluence_pairs = pair_list['Affluence']

df_dicts = []
for category, pairs in pair_list.items():
#     if not category == "Employment":
#       continue
    for decade in DECADES:
        #print(decade)
        for held_out_pair in pairs:
            other_pairs = [pair for pair in pairs if not pair == held_out_pair]
            #print(other_pairs)
            pos_vectors = []
            neg_vectors = []
            for pos, neg in other_pairs:
                maybe_pos_vec = get_vector(pos, decade)
                maybe_neg_vec = get_vector(neg, decade)
                if maybe_pos_vec is not None and maybe_neg_vec is not None:
                    pos_vectors.append(maybe_pos_vec)
                    neg_vectors.append(maybe_neg_vec)
            main_vec = sum(pos_vectors) - sum(neg_vectors)
            held_out_pos, held_out_neg = held_out_pair
            maybe_pos_vec = get_vector(held_out_pos, decade)
            maybe_neg_vec = get_vector(held_out_neg, decade)
            if maybe_pos_vec is not None and maybe_neg_vec is not None:
                df_dicts.append({
                    "decade": decade,
                    "category": category,
                    "pair": f"{held_out_pos},{held_out_neg}",
                    "pos_cosine": cosine(maybe_pos_vec, main_vec),
                    "neg_cosine": cosine(maybe_neg_vec, main_vec),
                })

# %%
held_out_df = pd.DataFrame(df_dicts)

plt.figure(figsize=(4, 10), dpi=100)
decade_df = held_out_df.loc[(held_out_df['decade'] == "1910") & (held_out_df['category'] == "Employment")]
my_range = list(decade_df['pair'])
sns.scatterplot(y=my_range, x=decade_df["pos_cosine"],)
sns.scatterplot(y=my_range, x=decade_df["neg_cosine"], color='red')
plt.hlines(y=my_range, xmin=decade_df["neg_cosine"], xmax=decade_df["pos_cosine"], color='grey', alpha=0.4)

# %%
decade_inversion_counts = collections.defaultdict(lambda:collections.defaultdict(list))

for row in held_out_df.itertuples():
    value = 1 if row.pos_cosine > row.neg_cosine else 0
    decade_inversion_counts[row.category][row.decade].append(value)

# %%
inversion_df_dicts = []
for k, v in decade_inversion_counts.items():
    for a, b in v.items():
        inversion_df_dicts.append({
            "category":k,
        "decade":a,
        "inversions":1.0 - sum(b)/len(b)})
f = pd.DataFrame.from_dict(inversion_df_dicts).pivot("category", "decade", "inversions")
sns.heatmap(f)
# Out:
# <AxesSubplot:xlabel='decade', ylabel='category'>

# %%
def find_nearest_neighbors(vector, all_vecs):
    return np.argsort(np.dot(all_vecs, -vector))

from termcolor import colored

def print_color_row(indices, all_words, pos_words, neg_words):
    result = ""
    c = "█"
    for i in indices:
        word = all_words[i]
        if word in pos_words:
            result += colored(c, 'blue')
        elif word in neg_words:
            result += colored(c, 'red')
        else:
            result += c
    return result

# for category, pairs in pair_list.items():
#     pos_pool, neg_pool = zip(*pairs)
    
#     for decade, decade_vecs in vector_maps.items():
        
#         pos_vecs = [decade_vecs[pos] for pos in pos_pool if pos in decade_vecs] # Not checking for zero vecs because it won't matter
#         neg_vecs = [decade_vecs[neg] for neg in neg_pool if neg in decade_vecs] # Not checking for zero vecs because it won't matter
        
#         diff_vec = sum(pos_vecs)/len(pos_vecs) - sum(neg_vecs)/len(neg_vecs)
#         diff_vec = diff_vec/np.linalg.norm(diff_vec)
        
#         all_words = sorted(decade_vecs.keys())
#         all_vecs = [decade_vecs[word] for word in all_words]
#         all_vecs_array = np.stack(all_vecs, axis=0)
#         indices = find_nearest_neighbors(diff_vec, all_vecs_array)

#         print(print_color_row(indices[:100], all_words, pos_pool, neg_pool) + f"\t{category}, {decade}")
#         print(print_color_row(indices[-100:], all_words, pos_pool, neg_pool))
        
#         for i in indices[:20]:
#             print(all_words[i])
        
#     print()

# %%
def get_dimension_vector(decade, pair_list):
    pos_vectors = []
    neg_vectors = []
    for pos, neg in pair_list:
        maybe_pos_vec = get_vector(pos, decade)
        maybe_neg_vec = get_vector(neg, decade)
        if maybe_pos_vec is not None and maybe_neg_vec is not None:
            pos_vectors.append(maybe_pos_vec)
            neg_vectors.append(maybe_neg_vec)
    return sum(pos_vectors) - sum(neg_vectors)
        
final_dimension_vectors = collections.defaultdict(dict)
for decade in DECADES:
    for category, pairs in pair_list.items():
        final_dimension_vectors[decade][category] = get_dimension_vector(decade, pairs)

# %%
AFFLUENCE = "Affluence"

def order_by_cosine(cosines):
    sorted_pairs = list(reversed(sorted(cosines.items(), key=lambda x:x[1])))
    return [x[0] for x in sorted_pairs]

def build_cosine_progress_plot(main_dimension):
    df_dicts = []
    for decade, category_dims in final_dimension_vectors.items():
        cosines = {}
        affluence_dimension = category_dims[main_dimension]
        for category, dimension in category_dims.items():
            if category == main_dimension:
                continue
            cosines[category] = cosine(affluence_dimension, dimension)
        order = order_by_cosine(cosines)
        for i, dim in enumerate(order):
            df_dicts.append({
                "rank": i+1,
                "dim": dim,
                "decade": decade,
            })
    return pd.DataFrame.from_dict(df_dicts).pivot("dim", "decade", "rank").reset_index()

# %%
from pandas.plotting import parallel_coordinates

def get_x_y_from_idx(idx):
    return int(idx/4), idx % 4

fig, axs = plt.subplots(4, 2, sharex=True,figsize=(10,10))

for i, dimension in enumerate(DIMENSIONS):
    x, y = get_x_y_from_idx(i)
    ax = axs[y][x]
    dimension_df = build_cosine_progress_plot(dimension)
    parallel_coordinates(dimension_df,"dim",
                         color=[COLOR_DICT[x] for x in dimension_df.dim],
                         axvlines=False, ax=ax)
    ax.invert_yaxis()
    ax.grid(False)
    ax.title.set_text(dimension)
    ax.set_ylabel('Rank')
    ax.get_legend().remove()
    ax.set_yticks(list(reversed(range(1,8))))
    if i ==0:
        fig.legend(loc="lower center", ncol=7)

# %%
myvecs = vector_maps["1990"]

# %%
diff = get_vector("rich", "1990") - get_vector( "poor", "1990")

# %%
all_words = sorted(myvecs.keys())
all_vecs = [myvecs[word] for word in all_words]
all_vecs_array = np.stack(all_vecs, axis=0)
df_dicts = []
for i, (word, vec) in tqdm(list(enumerate(myvecs.items()))):
    if not sum(vec):
        continue
    new_word_vec = vec + diff
    new_word_vec = new_word_vec/np.linalg.norm(new_word_vec)
    nearest_neighbor_index = find_nearest_neighbors(new_word_vec, all_vecs_array)[0]
    if not all_words[nearest_neighbor_index] == word:
        nearest_neighbor_vec = all_vecs_array[nearest_neighbor_index]
        df_dicts.append({
            "word": word,
            "rank": i,
            "nearest_neighbor": all_words[nearest_neighbor_index],
            "closeness":cosine(new_word_vec, nearest_neighbor_vec),
            "rich_cosine": cosine(myvecs['rich'], new_word_vec),
            "poor_cosine": cosine(myvecs['poor'], new_word_vec)
        })
    if i % 1000 == 0:
        print(len(df_dicts))
# Out:
#   0%|                                         | 10/100000 [00:00<36:53, 45.17it/s]
# 0
#   1%|▍                                      | 1007/100000 [00:20<33:05, 49.85it/s]
# 1
#   2%|▊                                      | 2010/100000 [00:40<31:51, 51.26it/s]
# 1
#   3%|█▏                                     | 3007/100000 [01:00<33:01, 48.95it/s]
# 2
#   4%|█▌                                     | 4007/100000 [01:20<30:00, 53.32it/s]
# 2
#   5%|█▉                                     | 5008/100000 [01:40<30:09, 52.49it/s]
# 2
#   6%|██▎                                    | 6011/100000 [12:33<30:19, 51.65it/s]
# 2
#   7%|██▋                                    | 7010/100000 [12:53<30:45, 50.39it/s]
# 4
#   8%|███                                    | 8010/100000 [13:12<30:10, 50.80it/s]
# 5
#   9%|███▌                                   | 9007/100000 [13:32<30:03, 50.44it/s]
# 7
#  10%|███▊                                  | 10007/100000 [13:52<30:24, 49.32it/s]
# 8
#  11%|████▏                                 | 11006/100000 [14:12<29:46, 49.81it/s]
# 9
#  12%|████▌                                 | 12008/100000 [14:33<29:24, 49.86it/s]
# 11
#  13%|████▉                                 | 13011/100000 [14:53<29:22, 49.35it/s]
# 11
#  14%|█████▎                                | 14009/100000 [15:14<34:12, 41.90it/s]
# 11
#  15%|█████▋                                | 15006/100000 [15:37<28:08, 50.33it/s]
# 11
#  16%|██████                                | 16006/100000 [15:57<27:33, 50.79it/s]
# 11
#  17%|██████▍                               | 17008/100000 [16:18<28:17, 48.89it/s]
# 12
#  18%|██████▊                               | 18008/100000 [16:38<26:55, 50.74it/s]
# 12
#  19%|███████▏                              | 19008/100000 [16:58<26:45, 50.44it/s]
# 12
#  20%|███████▌                              | 20011/100000 [17:18<26:15, 50.77it/s]
# 12
#  21%|███████▉                              | 21010/100000 [17:38<25:50, 50.95it/s]
# 12
#  22%|████████▎                             | 22011/100000 [17:58<25:38, 50.70it/s]
# 12
#  23%|████████▋                             | 23007/100000 [18:17<25:29, 50.34it/s]
# 12
#  24%|█████████                             | 24009/100000 [18:39<25:24, 49.83it/s]
# 12
#  25%|█████████▌                            | 25006/100000 [18:59<24:42, 50.60it/s]
# 12
#  26%|█████████▉                            | 26010/100000 [19:20<24:26, 50.44it/s]
# 12
#  27%|██████████▎                           | 27011/100000 [19:40<24:12, 50.25it/s]
# 12
#  28%|██████████▋                           | 28008/100000 [20:00<23:45, 50.51it/s]
# 12
#  29%|███████████                           | 29006/100000 [20:19<23:38, 50.03it/s]
# 13
#  30%|███████████▍                          | 30009/100000 [20:40<24:13, 48.17it/s]
# 13
#  31%|███████████▊                          | 31009/100000 [21:01<24:50, 46.29it/s]
# 13
#  32%|████████████▏                         | 32009/100000 [21:22<22:18, 50.81it/s]
# 13
#  33%|████████████▌                         | 33006/100000 [21:41<21:51, 51.09it/s]
# 13
#  34%|████████████▉                         | 34008/100000 [22:01<21:33, 51.01it/s]
# 13
#  35%|█████████████▎                        | 35009/100000 [22:21<23:13, 46.64it/s]
# 13
#  36%|█████████████▋                        | 36006/100000 [22:41<21:02, 50.67it/s]
# 13
#  37%|██████████████                        | 37006/100000 [23:01<20:41, 50.75it/s]
# 13
#  38%|██████████████▍                       | 38006/100000 [23:21<20:22, 50.71it/s]
# 13
#  39%|██████████████▊                       | 39007/100000 [23:43<25:11, 40.34it/s]
# 13
#  40%|███████████████▏                      | 40010/100000 [24:05<20:53, 47.84it/s]
# 13
#  41%|███████████████▌                      | 41011/100000 [24:25<19:52, 49.45it/s]
# 13
#  42%|███████████████▉                      | 42006/100000 [24:46<19:03, 50.72it/s]
# 13
#  43%|████████████████▎                     | 43008/100000 [25:06<18:42, 50.79it/s]
# 13
#  44%|████████████████▋                     | 44006/100000 [25:26<19:33, 47.71it/s]
# 13
#  45%|█████████████████                     | 45007/100000 [25:47<18:23, 49.83it/s]
# 13
#  46%|█████████████████▍                    | 46006/100000 [26:07<19:17, 46.64it/s]
# 13
#  47%|█████████████████▊                    | 47010/100000 [26:28<17:59, 49.07it/s]
# 13
#  48%|██████████████████▏                   | 48007/100000 [26:48<18:11, 47.64it/s]
# 13
#  49%|██████████████████▌                   | 49010/100000 [27:09<17:55, 47.40it/s]
# 13
#  50%|███████████████████                   | 50010/100000 [27:29<16:46, 49.68it/s]
# 13
#  51%|███████████████████▍                  | 51010/100000 [27:50<15:56, 51.22it/s]
# 13
#  52%|███████████████████▊                  | 52009/100000 [28:09<16:16, 49.16it/s]
# 13
#  53%|████████████████████▏                 | 53010/100000 [28:29<16:02, 48.80it/s]
# 14
#  54%|████████████████████▌                 | 54007/100000 [28:49<15:00, 51.09it/s]
# 14
#  55%|████████████████████▉                 | 55007/100000 [29:09<14:54, 50.32it/s]
# 14
#  56%|█████████████████████▎                | 56011/100000 [29:30<14:51, 49.37it/s]
# 14
#  57%|█████████████████████▋                | 57006/100000 [29:50<16:26, 43.60it/s]
# 14
#  58%|██████████████████████                | 58009/100000 [30:14<14:34, 47.99it/s]
# 14
#  59%|██████████████████████▍               | 59010/100000 [30:34<14:13, 48.01it/s]
# 14
#  60%|██████████████████████▊               | 60006/100000 [30:55<13:11, 50.54it/s]
# 14
#  61%|███████████████████████▏              | 61008/100000 [31:15<13:37, 47.71it/s]
# 14
#  62%|███████████████████████▌              | 62007/100000 [31:35<12:39, 50.05it/s]
# 14
#  63%|███████████████████████▉              | 63006/100000 [31:56<12:01, 51.25it/s]
# 14
#  64%|████████████████████████▎             | 64008/100000 [32:15<11:42, 51.20it/s]
# 14
#  65%|████████████████████████▋             | 65010/100000 [32:35<11:24, 51.10it/s]
# 18
#  66%|█████████████████████████             | 66006/100000 [32:54<11:06, 50.98it/s]
# 127
#  67%|█████████████████████████▍            | 67008/100000 [33:14<10:48, 50.90it/s]
# 221
#  68%|█████████████████████████▊            | 68009/100000 [33:34<10:24, 51.19it/s]
# 293
#  69%|██████████████████████████▏           | 69011/100000 [33:53<10:11, 50.69it/s]
# 341
#  70%|██████████████████████████▌           | 70007/100000 [34:13<09:53, 50.51it/s]
# 370
#  71%|██████████████████████████▉           | 71008/100000 [34:33<09:33, 50.53it/s]
# 436
# 100%|█████████████████████████████████████| 100000/100000 [34:35<00:00, 48.18it/s]

# %%
df_dicts
# Out:
# [{'word': 'poor',
#   'rank': 809,
#   'nearest_neighbor': 'rich',
#   'closeness': 1.0000000000000002,
#   'rich_cosine': 1.0000000000000002,
#   'poor_cosine': 0.3614056051885565},
#  {'word': 'sick',
#   'rank': 2636,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.5400316662437016,
#   'rich_cosine': 0.5400316662437016,
#   'poor_cosine': -0.20371673760272638},
#  {'word': 'unemployed',
#   'rank': 6438,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.532742384103396,
#   'rich_cosine': 0.532742384103396,
#   'poor_cosine': -0.20181024900650626},
#  {'word': 'oppressed',
#   'rank': 6911,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.6073944564866621,
#   'rich_cosine': 0.6073944564866621,
#   'poor_cosine': -0.1855205948148286},
#  {'word': 'poorest',
#   'rank': 7874,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.6063345786892196,
#   'rich_cosine': 0.6063345786892196,
#   'poor_cosine': -0.17736540766183695},
#  {'word': 'homeless',
#   'rank': 8452,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.5268491849720506,
#   'rich_cosine': 0.5268491849720506,
#   'poor_cosine': -0.21326083687278005},
#  {'word': 'plight',
#   'rank': 8897,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.5739443860251291,
#   'rich_cosine': 0.5739443860251291,
#   'poor_cosine': -0.1775043378446506},
#  {'word': 'poorer',
#   'rank': 9206,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.66874802472531,
#   'rich_cosine': 0.66874802472531,
#   'poor_cosine': -0.10833475521242976},
#  {'word': 'disadvantaged',
#   'rank': 10123,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.5142208906463521,
#   'rich_cosine': 0.5142208906463521,
#   'poor_cosine': -0.20335431844865182},
#  {'word': 'wretched',
#   'rank': 11492,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.5824025197899141,
#   'rich_cosine': 0.5824025197899141,
#   'poor_cosine': -0.1927904109736516},
#  {'word': 'needy',
#   'rank': 11571,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.6633544371331973,
#   'rich_cosine': 0.6633544371331973,
#   'poor_cosine': -0.09944439387448575},
#  {'word': 'destitute',
#   'rank': 16193,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.58871178389637,
#   'rich_cosine': 0.58871178389637,
#   'poor_cosine': -0.17488194085558187},
#  {'word': 'downtrodden',
#   'rank': 28494,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.663063199611645,
#   'rich_cosine': 0.663063199611645,
#   'poor_cosine': -0.13837476176781818},
#  {'word': 'almanack',
#   'rank': 52791,
#   'nearest_neighbor': 'rich',
#   'closeness': 0.6002734793306858,
#   'rich_cosine': 0.6002734793306858,
#   'poor_cosine': -0.19648627729789314},
#  {'word': 'parishioner',
#   'rank': 64850,
#   'nearest_neighbor': 'wordes',
#   'closeness': 0.6562188830934262,
#   'rich_cosine': 0.463654788062608,
#   'poor_cosine': -0.37206210752885865},
#  {'word': 'dissembled',
#   'rank': 64965,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6747645734289568,
#   'rich_cosine': 0.47215929367829845,
#   'poor_cosine': -0.36928107660638537},
#  {'word': 'preponderate',
#   'rank': 64971,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6718944906925701,
#   'rich_cosine': 0.468558349230306,
#   'poor_cosine': -0.36846330442763536},
#  {'word': 'dogmatically',
#   'rank': 64980,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6519379030768403,
#   'rich_cosine': 0.4358749507335032,
#   'poor_cosine': -0.39224518035518907},
#  {'word': 'pryer',
#   'rank': 65002,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6769841903601928,
#   'rich_cosine': 0.4593223728213038,
#   'poor_cosine': -0.3766919601697974},
#  {'word': 'crooning',
#   'rank': 65008,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6620554046898283,
#   'rich_cosine': 0.48042278054772236,
#   'poor_cosine': -0.36186725030323985},
#  {'word': 'lawmaker',
#   'rank': 65012,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6713970116993315,
#   'rich_cosine': 0.4541903403024391,
#   'poor_cosine': -0.3813451723676598},
#  {'word': 'awestruck',
#   'rank': 65022,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6659168224790383,
#   'rich_cosine': 0.48458344682491283,
#   'poor_cosine': -0.360317383764417},
#  {'word': 'homewards',
#   'rank': 65049,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.676266048461811,
#   'rich_cosine': 0.4673964695446261,
#   'poor_cosine': -0.3700615495212516},
#  {'word': 'misconstruction',
#   'rank': 65053,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6723728400353789,
#   'rich_cosine': 0.4539193015415431,
#   'poor_cosine': -0.3809946816814079},
#  {'word': 'farrier',
#   'rank': 65058,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6558665197579748,
#   'rich_cosine': 0.4607826371933296,
#   'poor_cosine': -0.37637181040355383},
#  {'word': 'unfitting',
#   'rank': 65068,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6573289988266616,
#   'rich_cosine': 0.4642548444140994,
#   'poor_cosine': -0.3711692956605235},
#  {'word': 'provisos',
#   'rank': 65073,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6748565081497736,
#   'rich_cosine': 0.4663167513999931,
#   'poor_cosine': -0.37364890204570445},
#  {'word': 'sotherton',
#   'rank': 65082,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6826615497019807,
#   'rich_cosine': 0.4616980117410547,
#   'poor_cosine': -0.372127893561493},
#  {'word': 'delightedly',
#   'rank': 65084,
#   'nearest_neighbor': 'cadaverous',
#   'closeness': 0.6502215006000558,
#   'rich_cosine': 0.4639549883018607,
#   'poor_cosine': -0.37116579964282825},
#  {'word': 'saviors',
#   'rank': 65101,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6564461571591248,
#   'rich_cosine': 0.4752075815669021,
#   'poor_cosine': -0.3595553678932225},
#  {'word': 'kalpa',
#   'rank': 65109,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6705304753550937,
#   'rich_cosine': 0.4630523871579001,
#   'poor_cosine': -0.3747837330081491},
#  {'word': 'hefted',
#   'rank': 65124,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6565425218919496,
#   'rich_cosine': 0.45145438843591557,
#   'poor_cosine': -0.38453939283184263},
#  {'word': 'univocal',
#   'rank': 65125,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6687613662610719,
#   'rich_cosine': 0.4551158425564924,
#   'poor_cosine': -0.37746437971566194},
#  {'word': 'intermeddle',
#   'rank': 65128,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6579847125168014,
#   'rich_cosine': 0.4763556357949074,
#   'poor_cosine': -0.36103403368671505},
#  {'word': 'voluble',
#   'rank': 65133,
#   'nearest_neighbor': 'inane',
#   'closeness': 0.6558357170154685,
#   'rich_cosine': 0.4869695556194622,
#   'poor_cosine': -0.3536385488523328},
#  {'word': 'twirl',
#   'rank': 65153,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.66426646024532,
#   'rich_cosine': 0.46792501634562284,
#   'poor_cosine': -0.3752671103719393},
#  {'word': 'procrastinate',
#   'rank': 65172,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6732033619488216,
#   'rich_cosine': 0.47209491995310343,
#   'poor_cosine': -0.36236252546863773},
#  {'word': 'siphoned',
#   'rank': 65190,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.663614825714601,
#   'rich_cosine': 0.4746345050919999,
#   'poor_cosine': -0.35682645472062025},
#  {'word': 'kinswoman',
#   'rank': 65201,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6722079535844823,
#   'rich_cosine': 0.47514727257156253,
#   'poor_cosine': -0.3575126048061044},
#  {'word': 'devastations',
#   'rank': 65202,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6627184868823373,
#   'rich_cosine': 0.46132227841742746,
#   'poor_cosine': -0.3670450052256354},
#  {'word': 'disfranchised',
#   'rank': 65210,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.678877974102331,
#   'rich_cosine': 0.4763596348849874,
#   'poor_cosine': -0.3590282014217431},
#  {'word': 'peeps',
#   'rank': 65211,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6719431491169637,
#   'rich_cosine': 0.46593726349485837,
#   'poor_cosine': -0.3781323366356437},
#  {'word': 'hesitatingly',
#   'rank': 65212,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6709760368699996,
#   'rich_cosine': 0.46915842553555526,
#   'poor_cosine': -0.3671213200319306},
#  {'word': 'humorously',
#   'rank': 65217,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6731829435494602,
#   'rich_cosine': 0.46391230646820625,
#   'poor_cosine': -0.3707558722064636},
#  {'word': 'ibidem',
#   'rank': 65221,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.676084829375609,
#   'rich_cosine': 0.4655043409480054,
#   'poor_cosine': -0.37438165658555655},
#  {'word': 'egged',
#   'rank': 65254,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6738525562665444,
#   'rich_cosine': 0.4696362114183016,
#   'poor_cosine': -0.3700051930859046},
#  {'word': 'necessitous',
#   'rank': 65273,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6653802363002912,
#   'rich_cosine': 0.4882608560019718,
#   'poor_cosine': -0.34600417978262943},
#  {'word': 'percipient',
#   'rank': 65284,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6740434953637613,
#   'rich_cosine': 0.4638315884167468,
#   'poor_cosine': -0.3789859945498066},
#  {'word': 'almshouses',
#   'rank': 65289,
#   'nearest_neighbor': 'penitentiaries',
#   'closeness': 0.5794877790756052,
#   'rich_cosine': 0.47876198461709935,
#   'poor_cosine': -0.30247316522629586},
#  {'word': 'wronging',
#   'rank': 65290,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.643736817664181,
#   'rich_cosine': 0.4747311909837055,
#   'poor_cosine': -0.3556136782003353},
#  {'word': 'fairyland',
#   'rank': 65295,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6677520118019961,
#   'rich_cosine': 0.4779721555033995,
#   'poor_cosine': -0.3657062372982617},
#  {'word': 'pettiness',
#   'rank': 65309,
#   'nearest_neighbor': 'inane',
#   'closeness': 0.6578824763355559,
#   'rich_cosine': 0.47821827607168865,
#   'poor_cosine': -0.35827786342810397},
#  {'word': 'dashwoods',
#   'rank': 65335,
#   'nearest_neighbor': 'matty',
#   'closeness': 0.6513666590626991,
#   'rich_cosine': 0.4720920294774625,
#   'poor_cosine': -0.3600101364594473},
#  {'word': 'disproportioned',
#   'rank': 65364,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6625036979569374,
#   'rich_cosine': 0.4737466853608839,
#   'poor_cosine': -0.3654224185809969},
#  {'word': 'superscription',
#   'rank': 65366,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.666508170745951,
#   'rich_cosine': 0.4752865937687926,
#   'poor_cosine': -0.35439253774574014},
#  {'word': 'acquaints',
#   'rank': 65374,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.653763353527614,
#   'rich_cosine': 0.49493530757541,
#   'poor_cosine': -0.33613686999796544},
#  {'word': 'stoical',
#   'rank': 65375,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6720613730736096,
#   'rich_cosine': 0.4708900710483841,
#   'poor_cosine': -0.3619495197212688},
#  {'word': 'scamper',
#   'rank': 65377,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.673528236325487,
#   'rich_cosine': 0.4699351230317991,
#   'poor_cosine': -0.3688217927840471},
#  {'word': 'stewardess',
#   'rank': 65414,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6669438867630129,
#   'rich_cosine': 0.45101164482759093,
#   'poor_cosine': -0.3811586119197918},
#  {'word': 'forborne',
#   'rank': 65435,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6732880864234209,
#   'rich_cosine': 0.4649365355846683,
#   'poor_cosine': -0.3704034055195516},
#  {'word': 'leaguer',
#   'rank': 65451,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6576271242858357,
#   'rich_cosine': 0.45470904676628904,
#   'poor_cosine': -0.3799130976677686},
#  {'word': 'oarsmen',
#   'rank': 65456,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6750668276565007,
#   'rich_cosine': 0.4623590009356312,
#   'poor_cosine': -0.3756905418348846},
#  {'word': 'straker',
#   'rank': 65473,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.65615431499291,
#   'rich_cosine': 0.4715435076038669,
#   'poor_cosine': -0.36649282809633543},
#  {'word': 'thunderclap',
#   'rank': 65478,
#   'nearest_neighbor': 'phosphorescent',
#   'closeness': 0.6495623932960748,
#   'rich_cosine': 0.4685079082956369,
#   'poor_cosine': -0.3619691075458623},
#  {'word': 'unseat',
#   'rank': 65486,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6625561365317706,
#   'rich_cosine': 0.45300768082039433,
#   'poor_cosine': -0.3772725070252411},
#  {'word': 'smirked',
#   'rank': 65497,
#   'nearest_neighbor': 'tori',
#   'closeness': 0.6561207166722453,
#   'rich_cosine': 0.4584404315942501,
#   'poor_cosine': -0.3809522935208038},
#  {'word': 'friendlier',
#   'rank': 65501,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6720704892565612,
#   'rich_cosine': 0.4789343081601115,
#   'poor_cosine': -0.3608109193313648},
#  {'word': 'agriculturist',
#   'rank': 65508,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6689442983946078,
#   'rich_cosine': 0.47374152313048146,
#   'poor_cosine': -0.36890661878725206},
#  {'word': 'messrs',
#   'rank': 65516,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6689825065942664,
#   'rich_cosine': 0.4644994066520474,
#   'poor_cosine': -0.3777883904663562},
#  {'word': 'curtsey',
#   'rank': 65523,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6634085893519004,
#   'rich_cosine': 0.4615755724454856,
#   'poor_cosine': -0.37801855810637647},
#  {'word': 'marshaled',
#   'rank': 65553,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6579586047573216,
#   'rich_cosine': 0.4753206388298291,
#   'poor_cosine': -0.3646859133566368},
#  {'word': 'queued',
#   'rank': 65558,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6640985598921209,
#   'rich_cosine': 0.4553212471775651,
#   'poor_cosine': -0.3823913546295969},
#  {'word': 'bedevilled',
#   'rank': 65567,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6821316279303854,
#   'rich_cosine': 0.4718402342475999,
#   'poor_cosine': -0.36081297422315006},
#  {'word': 'trantridge',
#   'rank': 65574,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6720256196073474,
#   'rich_cosine': 0.47162504561854257,
#   'poor_cosine': -0.36797266968779113},
#  {'word': 'inveighed',
#   'rank': 65579,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6558165190026186,
#   'rich_cosine': 0.4648040777141698,
#   'poor_cosine': -0.36874073020075565},
#  {'word': 'prosperously',
#   'rank': 65584,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6665113126938335,
#   'rich_cosine': 0.461403385012056,
#   'poor_cosine': -0.37064421356719074},
#  {'word': 'upanishad',
#   'rank': 65611,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6617496771418344,
#   'rich_cosine': 0.4470072195711012,
#   'poor_cosine': -0.39280245093073657},
#  {'word': 'falters',
#   'rank': 65612,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6546623534516368,
#   'rich_cosine': 0.4642643501833767,
#   'poor_cosine': -0.36999974368403316},
#  {'word': 'commensurable',
#   'rank': 65616,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.677970419787565,
#   'rich_cosine': 0.4649379355118507,
#   'poor_cosine': -0.3716474073301023},
#  {'word': 'clairvoyant',
#   'rank': 65619,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6696723218453057,
#   'rich_cosine': 0.47084873535218874,
#   'poor_cosine': -0.37235818257975634},
#  {'word': 'paterfamilias',
#   'rank': 65621,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6726116667927793,
#   'rich_cosine': 0.4542351796836532,
#   'poor_cosine': -0.37813913101111557},
#  {'word': 'allegiances',
#   'rank': 65639,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6587289444597743,
#   'rich_cosine': 0.460741373153163,
#   'poor_cosine': -0.37592128140286574},
#  {'word': 'incognito',
#   'rank': 65651,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6780826562021034,
#   'rich_cosine': 0.46980939568344277,
#   'poor_cosine': -0.36568242262404344},
#  {'word': 'bluntness',
#   'rank': 65656,
#   'nearest_neighbor': 'inane',
#   'closeness': 0.6583138282792695,
#   'rich_cosine': 0.46445626382530075,
#   'poor_cosine': -0.3689273565317472},
#  {'word': 'propounding',
#   'rank': 65659,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6678236980184599,
#   'rich_cosine': 0.439968033490755,
#   'poor_cosine': -0.39106663204397313},
#  {'word': 'agonize',
#   'rank': 65704,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6760617298288321,
#   'rich_cosine': 0.46434273757561934,
#   'poor_cosine': -0.373379734873894},
#  {'word': 'leered',
#   'rank': 65706,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6686993875931291,
#   'rich_cosine': 0.4592024288488497,
#   'poor_cosine': -0.37924327973159616},
#  {'word': 'puir',
#   'rank': 65721,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6612006797046165,
#   'rich_cosine': 0.4888101954613597,
#   'poor_cosine': -0.3522929670707045},
#  {'word': 'drover',
#   'rank': 65735,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6672480093949792,
#   'rich_cosine': 0.4780067200974188,
#   'poor_cosine': -0.36760830650012927},
#  {'word': 'archly',
#   'rank': 65739,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6705121070144765,
#   'rich_cosine': 0.4683329679647117,
#   'poor_cosine': -0.3666878451912173},
#  {'word': 'dished',
#   'rank': 65757,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6714696919052193,
#   'rich_cosine': 0.4756364554327085,
#   'poor_cosine': -0.3616260971644441},
#  {'word': 'wantin',
#   'rank': 65763,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6713566822385527,
#   'rich_cosine': 0.47651400546546946,
#   'poor_cosine': -0.36242133839672525},
#  {'word': 'stuttered',
#   'rank': 65771,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6602983492252795,
#   'rich_cosine': 0.45559568092056274,
#   'poor_cosine': -0.37776506355188283},
#  {'word': 'baldly',
#   'rank': 65774,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6571606892005623,
#   'rich_cosine': 0.4355747938869782,
#   'poor_cosine': -0.3929846684911611},
#  {'word': 'sickbed',
#   'rank': 65783,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6568559682075484,
#   'rich_cosine': 0.47764607599785885,
#   'poor_cosine': -0.3600975565268683},
#  {'word': 'crazily',
#   'rank': 65788,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6625605568354768,
#   'rich_cosine': 0.464982251280087,
#   'poor_cosine': -0.37999616527840047},
#  {'word': 'revellers',
#   'rank': 65797,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6674434005492917,
#   'rich_cosine': 0.46046802193430797,
#   'poor_cosine': -0.3785306971281094},
#  {'word': 'meanes',
#   'rank': 65798,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6735639098315128,
#   'rich_cosine': 0.47113279218008475,
#   'poor_cosine': -0.37274518569707527},
#  {'word': 'undeviating',
#   'rank': 65800,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6576295596787106,
#   'rich_cosine': 0.4640906655374148,
#   'poor_cosine': -0.3664143630859071},
#  {'word': 'soldierly',
#   'rank': 65802,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6477569417363198,
#   'rich_cosine': 0.4867644270901855,
#   'poor_cosine': -0.347946504044818},
#  {'word': 'bludgeon',
#   'rank': 65814,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6699441747855472,
#   'rich_cosine': 0.4658550190511758,
#   'poor_cosine': -0.37158366834153306},
#  {'word': 'worshiper',
#   'rank': 65828,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6647211981299588,
#   'rich_cosine': 0.4742014948792639,
#   'poor_cosine': -0.3724796037847163},
#  {'word': 'tweak',
#   'rank': 65840,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6709144793134783,
#   'rich_cosine': 0.46727543768126867,
#   'poor_cosine': -0.3727522424682267},
#  {'word': 'hamstrung',
#   'rank': 65849,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6793421610250344,
#   'rich_cosine': 0.47086111827381066,
#   'poor_cosine': -0.3606457643671705},
#  {'word': 'pinnace',
#   'rank': 65858,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.671868278719366,
#   'rich_cosine': 0.46759499223140427,
#   'poor_cosine': -0.3760421318381502},
#  {'word': 'traditionary',
#   'rank': 65859,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6760988469372414,
#   'rich_cosine': 0.4667622301976616,
#   'poor_cosine': -0.3724436408641544},
#  {'word': 'esteeming',
#   'rank': 65861,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6608875787151164,
#   'rich_cosine': 0.47801479044618983,
#   'poor_cosine': -0.3598771363334825},
#  {'word': 'gipsies',
#   'rank': 65864,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6719795019831671,
#   'rich_cosine': 0.47633800636528867,
#   'poor_cosine': -0.3645093119792946},
#  {'word': 'teems',
#   'rank': 65865,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6703591332698362,
#   'rich_cosine': 0.4729785194227476,
#   'poor_cosine': -0.37313930221164726},
#  {'word': 'wayfarers',
#   'rank': 65881,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6655669335519524,
#   'rich_cosine': 0.4736189060595283,
#   'poor_cosine': -0.3645160738826929},
#  {'word': 'fascinates',
#   'rank': 65890,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6741919422418542,
#   'rich_cosine': 0.4710032748466801,
#   'poor_cosine': -0.367618696102714},
#  {'word': 'farreaching',
#   'rank': 65908,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6677906187287467,
#   'rich_cosine': 0.465461380628852,
#   'poor_cosine': -0.3683838821148582},
#  {'word': 'stalwarts',
#   'rank': 65920,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6803738298752334,
#   'rich_cosine': 0.4610342065165584,
#   'poor_cosine': -0.37563212153359987},
#  {'word': 'volubility',
#   'rank': 65926,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6725174114028322,
#   'rich_cosine': 0.4625512762327087,
#   'poor_cosine': -0.3774681910590802},
#  {'word': 'remonstrating',
#   'rank': 65927,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6727880650410449,
#   'rich_cosine': 0.4719560874297416,
#   'poor_cosine': -0.35964216143566646},
#  {'word': 'disquietude',
#   'rank': 65929,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6743855146695302,
#   'rich_cosine': 0.4603501192470712,
#   'poor_cosine': -0.38094733994428986},
#  {'word': 'astonishes',
#   'rank': 65933,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6692440618496405,
#   'rich_cosine': 0.4745685968249355,
#   'poor_cosine': -0.3699670041034864},
#  {'word': 'complimenting',
#   'rank': 65939,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6771167252209379,
#   'rich_cosine': 0.47369240495972287,
#   'poor_cosine': -0.3646345510261412},
#  {'word': 'glares',
#   'rank': 65942,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.674100205646081,
#   'rich_cosine': 0.4755589297445862,
#   'poor_cosine': -0.36348977656273856},
#  {'word': 'intentness',
#   'rank': 65950,
#   'nearest_neighbor': 'inane',
#   'closeness': 0.658654681166639,
#   'rich_cosine': 0.4551034083562572,
#   'poor_cosine': -0.3782549158666228},
#  {'word': 'grete',
#   'rank': 65956,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6605026618020202,
#   'rich_cosine': 0.46342934355354126,
#   'poor_cosine': -0.3800162620839905},
#  {'word': 'slinking',
#   'rank': 65958,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6742438455565416,
#   'rich_cosine': 0.4660754486629503,
#   'poor_cosine': -0.3782316197509975},
#  {'word': 'inherence',
#   'rank': 65963,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6640220919079426,
#   'rich_cosine': 0.4641210181848032,
#   'poor_cosine': -0.3765717068395875},
#  {'word': 'millenniums',
#   'rank': 65964,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6590049606452102,
#   'rich_cosine': 0.4518941971042591,
#   'poor_cosine': -0.38301785891007},
#  {'word': 'purist',
#   'rank': 65966,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.679842313882816,
#   'rich_cosine': 0.4635637164034406,
#   'poor_cosine': -0.37449961303458634},
#  {'word': 'ramshackle',
#   'rank': 65983,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6713713977312845,
#   'rich_cosine': 0.4696954486280734,
#   'poor_cosine': -0.37155331896459076},
#  {'word': 'condole',
#   'rank': 66000,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6758728252312685,
#   'rich_cosine': 0.4693190684518881,
#   'poor_cosine': -0.3704993295620294},
#  {'word': 'maturer',
#   'rank': 66001,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6677453459526386,
#   'rich_cosine': 0.48069026432571554,
#   'poor_cosine': -0.362954168923206},
#  {'word': 'heartiness',
#   'rank': 66005,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.670466425736128,
#   'rich_cosine': 0.4739806844990735,
#   'poor_cosine': -0.36460540818009024},
#  {'word': 'repre',
#   'rank': 66015,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6613675407742702,
#   'rich_cosine': 0.45745733907697944,
#   'poor_cosine': -0.38304960035625135},
#  {'word': 'espouses',
#   'rank': 66023,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6588965976361462,
#   'rich_cosine': 0.4622419083467848,
#   'poor_cosine': -0.3726535180749897},
#  {'word': 'thousandfold',
#   'rank': 66027,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6580758373357188,
#   'rich_cosine': 0.46692156260822093,
#   'poor_cosine': -0.3720287337476368},
#  {'word': 'nastiest',
#   'rank': 66049,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6746518940546488,
#   'rich_cosine': 0.46641358398349564,
#   'poor_cosine': -0.36640629889124876},
#  {'word': 'sorrier',
#   'rank': 66052,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6699089893803551,
#   'rich_cosine': 0.46638120235003483,
#   'poor_cosine': -0.3747486584567874},
#  {'word': 'obituaries',
#   'rank': 66054,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6526346978536791,
#   'rich_cosine': 0.46826714299356337,
#   'poor_cosine': -0.36786171785440125},
#  {'word': 'centring',
#   'rank': 66061,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6753086490433756,
#   'rich_cosine': 0.4586199846846722,
#   'poor_cosine': -0.3816302232765012},
#  {'word': 'predetermine',
#   'rank': 66062,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6747594946582965,
#   'rich_cosine': 0.4610091082215616,
#   'poor_cosine': -0.37766722135785336},
#  {'word': 'somniferum',
#   'rank': 66075,
#   'nearest_neighbor': 'papaver',
#   'closeness': 0.6752171961709008,
#   'rich_cosine': 0.44188978340562063,
#   'poor_cosine': -0.4104654109926773},
#  {'word': 'shunning',
#   'rank': 66080,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6683971363601074,
#   'rich_cosine': 0.49019571188038924,
#   'poor_cosine': -0.33821524362729466},
#  {'word': 'lackey',
#   'rank': 66093,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6695952432315295,
#   'rich_cosine': 0.4710799991343039,
#   'poor_cosine': -0.36730368017455384},
#  {'word': 'elope',
#   'rank': 66096,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6537901861821755,
#   'rich_cosine': 0.47320220252153095,
#   'poor_cosine': -0.3614043305229709},
#  {'word': 'fagged',
#   'rank': 66109,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.672904787756125,
#   'rich_cosine': 0.47483442103449514,
#   'poor_cosine': -0.3657753155325243},
#  {'word': 'outflank',
#   'rank': 66190,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6593145328550339,
#   'rich_cosine': 0.4679059705289979,
#   'poor_cosine': -0.3695900935589337},
#  {'word': 'babo',
#   'rank': 66206,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6378292033966871,
#   'rich_cosine': 0.46080538340112104,
#   'poor_cosine': -0.3585275256652195},
#  {'word': 'commendations',
#   'rank': 66248,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6746566170588895,
#   'rich_cosine': 0.476399776071614,
#   'poor_cosine': -0.3616208682056917},
#  {'word': 'censuring',
#   'rank': 66249,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6555653469477754,
#   'rich_cosine': 0.45007580647967377,
#   'poor_cosine': -0.38458628610743234},
#  {'word': 'consolatory',
#   'rank': 66252,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6752777267207223,
#   'rich_cosine': 0.46948553859659325,
#   'poor_cosine': -0.36846159419781477},
#  {'word': 'unsuspicious',
#   'rank': 66253,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6684639818164364,
#   'rich_cosine': 0.46980752715543916,
#   'poor_cosine': -0.363540457618774},
#  {'word': 'unphilosophical',
#   'rank': 66258,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6823043438220493,
#   'rich_cosine': 0.45605178444742783,
#   'poor_cosine': -0.3772107748148771},
#  {'word': 'piquant',
#   'rank': 66264,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6743225580536648,
#   'rich_cosine': 0.4657280005148228,
#   'poor_cosine': -0.3758474709779766},
#  {'word': 'outpourings',
#   'rank': 66268,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.669705274706889,
#   'rich_cosine': 0.4852131232256959,
#   'poor_cosine': -0.34896105457744603},
#  {'word': 'nastiness',
#   'rank': 66274,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6689587372516929,
#   'rich_cosine': 0.4807061197151738,
#   'poor_cosine': -0.35921937297185774},
#  {'word': 'backer',
#   'rank': 66294,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6549503206729016,
#   'rich_cosine': 0.4423589849916214,
#   'poor_cosine': -0.39129942875202645},
#  {'word': 'materialised',
#   'rank': 66299,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6780022925841775,
#   'rich_cosine': 0.47230551460167863,
#   'poor_cosine': -0.36648293644788293},
#  {'word': 'vasudeva',
#   'rank': 66300,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6600532243996414,
#   'rich_cosine': 0.48115090850631315,
#   'poor_cosine': -0.36156298585893426},
#  {'word': 'pedant',
#   'rank': 66316,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6692354312101993,
#   'rich_cosine': 0.4714583137394454,
#   'poor_cosine': -0.37104495175888313},
#  {'word': 'monosyllables',
#   'rank': 66320,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6525011442887879,
#   'rich_cosine': 0.4757162978514165,
#   'poor_cosine': -0.35780946357940463},
#  {'word': 'sympathizes',
#   'rank': 66327,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6706385087315968,
#   'rich_cosine': 0.48513704227134635,
#   'poor_cosine': -0.3504697862570211},
#  {'word': 'shamelessly',
#   'rank': 66337,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6517122578607338,
#   'rich_cosine': 0.46937152192882703,
#   'poor_cosine': -0.3597408115331118},
#  {'word': 'nukuheva',
#   'rank': 66342,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6734995247608311,
#   'rich_cosine': 0.466522080154848,
#   'poor_cosine': -0.37187158069658266},
#  {'word': 'dejectedly',
#   'rank': 66347,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6660876628757012,
#   'rich_cosine': 0.4549747038630767,
#   'poor_cosine': -0.379486367151991},
#  {'word': 'tweedledee',
#   'rank': 66355,
#   'nearest_neighbor': 'wordes',
#   'closeness': 0.6608232154105627,
#   'rich_cosine': 0.45866350568710645,
#   'poor_cosine': -0.3834181332459365},
#  {'word': 'coverture',
#   'rank': 66386,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6600995453600023,
#   'rich_cosine': 0.4482586192679378,
#   'poor_cosine': -0.38582228937678764},
#  {'word': 'providentially',
#   'rank': 66387,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6780794845063315,
#   'rich_cosine': 0.4692324913561171,
#   'poor_cosine': -0.3695377681119742},
#  {'word': 'miscreants',
#   'rank': 66388,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6769571984034202,
#   'rich_cosine': 0.4690270950701819,
#   'poor_cosine': -0.36480692700702966},
#  {'word': 'interposes',
#   'rank': 66397,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.660475793847102,
#   'rich_cosine': 0.4638151557059001,
#   'poor_cosine': -0.3697798721808717},
#  {'word': 'eternities',
#   'rank': 66409,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6567670753074869,
#   'rich_cosine': 0.474818270101893,
#   'poor_cosine': -0.3660958561026259},
#  {'word': 'brierly',
#   'rank': 66417,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6768035132589827,
#   'rich_cosine': 0.4623147398582493,
#   'poor_cosine': -0.3730809424958519},
#  {'word': 'portends',
#   'rank': 66431,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6489364058559929,
#   'rich_cosine': 0.48910864151350714,
#   'poor_cosine': -0.31251728977042176},
#  {'word': 'subjoined',
#   'rank': 66464,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6757323270511769,
#   'rich_cosine': 0.46472692055559833,
#   'poor_cosine': -0.37735413708940035},
#  {'word': 'meyrick',
#   'rank': 66476,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6702491737321125,
#   'rich_cosine': 0.45370456831594197,
#   'poor_cosine': -0.39553376071620794},
#  {'word': 'litigations',
#   'rank': 66496,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6689641537966864,
#   'rich_cosine': 0.4606011921971922,
#   'poor_cosine': -0.37059396767605185},
#  {'word': 'doorsteps',
#   'rank': 66497,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6631064631422144,
#   'rich_cosine': 0.47237987493457123,
#   'poor_cosine': -0.37026771402229075},
#  {'word': 'undoes',
#   'rank': 66498,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6772405772154803,
#   'rich_cosine': 0.4671248115144096,
#   'poor_cosine': -0.3680893832565614},
#  {'word': 'convalescing',
#   'rank': 66508,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6550454587164002,
#   'rich_cosine': 0.4498313816633763,
#   'poor_cosine': -0.35678782830568373},
#  {'word': 'brutalized',
#   'rank': 66509,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.670945267129059,
#   'rich_cosine': 0.4874050028975782,
#   'poor_cosine': -0.3439739889685134},
#  {'word': 'congolese',
#   'rank': 66520,
#   'nearest_neighbor': 'wordes',
#   'closeness': 0.668288667860978,
#   'rich_cosine': 0.44795391611559915,
#   'poor_cosine': -0.3845480925335045},
#  {'word': 'catched',
#   'rank': 66550,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6676819295078742,
#   'rich_cosine': 0.4819531228913983,
#   'poor_cosine': -0.3627364679425733},
#  {'word': 'subdues',
#   'rank': 66551,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6668031193887077,
#   'rich_cosine': 0.4834062975634692,
#   'poor_cosine': -0.3523286793789726},
#  {'word': 'meriting',
#   'rank': 66552,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.675984774627258,
#   'rich_cosine': 0.46313276561049493,
#   'poor_cosine': -0.3733992473424504},
#  {'word': 'schoolmate',
#   'rank': 66561,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6535389861839098,
#   'rich_cosine': 0.4957839589294443,
#   'poor_cosine': -0.33789582905858506},
#  {'word': 'recrudescence',
#   'rank': 66570,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6673369092871579,
#   'rich_cosine': 0.450347692752455,
#   'poor_cosine': -0.37919229778371033},
#  {'word': 'kokua',
#   'rank': 66582,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6753332988511687,
#   'rich_cosine': 0.47230136007786966,
#   'poor_cosine': -0.3692243149489631},
#  {'word': 'soveraign',
#   'rank': 66596,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.680235653807619,
#   'rich_cosine': 0.46936879655875324,
#   'poor_cosine': -0.36725642213889875},
#  {'word': 'changeful',
#   'rank': 66618,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6784169579811565,
#   'rich_cosine': 0.4679318950264727,
#   'poor_cosine': -0.37144368609450296},
#  {'word': 'petulantly',
#   'rank': 66631,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6689610357834944,
#   'rich_cosine': 0.46866628143210115,
#   'poor_cosine': -0.37092861156359874},
#  {'word': 'vacillated',
#   'rank': 66652,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6731678438025066,
#   'rich_cosine': 0.4644072963540961,
#   'poor_cosine': -0.37465743831387316},
#  {'word': 'recommenced',
#   'rank': 66691,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.681295379054408,
#   'rich_cosine': 0.4674027902909444,
#   'poor_cosine': -0.36981297015431597},
#  {'word': 'donatists',
#   'rank': 66692,
#   'nearest_neighbor': 'orosius',
#   'closeness': 0.646345397260514,
#   'rich_cosine': 0.45209914410996843,
#   'poor_cosine': -0.3798016993867537},
#  {'word': 'speedier',
#   'rank': 66701,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6551845740705379,
#   'rich_cosine': 0.4546603541570676,
#   'poor_cosine': -0.37149044905209894},
#  {'word': 'strolls',
#   'rank': 66711,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.673876029008847,
#   'rich_cosine': 0.46512777690016677,
#   'poor_cosine': -0.3740962191264074},
#  {'word': 'tweedledum',
#   'rank': 66720,
#   'nearest_neighbor': 'wordes',
#   'closeness': 0.6643336558235665,
#   'rich_cosine': 0.44130318887262937,
#   'poor_cosine': -0.39867126963078087},
#  {'word': 'trumpery',
#   'rank': 66752,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6685426859263631,
#   'rich_cosine': 0.46403502454615664,
#   'poor_cosine': -0.37709910716763984},
#  {'word': 'underhand',
#   'rank': 66753,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6793261108566254,
#   'rich_cosine': 0.46618638447336785,
#   'poor_cosine': -0.3695342276262827},
#  {'word': 'loafer',
#   'rank': 66774,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6759608384570877,
#   'rich_cosine': 0.47497995839871926,
#   'poor_cosine': -0.3606198173886641},
#  {'word': 'overshadows',
#   'rank': 66775,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6598199182076157,
#   'rich_cosine': 0.466025529341961,
#   'poor_cosine': -0.3757793141239909},
#  {'word': 'wavers',
#   'rank': 66779,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.676533033419956,
#   'rich_cosine': 0.4787215431923444,
#   'poor_cosine': -0.35986790814193886},
#  {'word': 'bleakness',
#   'rank': 66790,
#   'nearest_neighbor': 'inane',
#   'closeness': 0.648814961641286,
#   'rich_cosine': 0.48362825017502603,
#   'poor_cosine': -0.3457904069958127},
#  {'word': 'distempers',
#   'rank': 66807,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6791946710491998,
#   'rich_cosine': 0.4666613979119294,
#   'poor_cosine': -0.3675866709113433},
#  {'word': 'prepossessions',
#   'rank': 66810,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6785047126206223,
#   'rich_cosine': 0.46756588507800695,
#   'poor_cosine': -0.36711256293335376},
#  {'word': 'requited',
#   'rank': 66811,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6743814156542306,
#   'rich_cosine': 0.49454084767082196,
#   'poor_cosine': -0.3386807707304843},
#  {'word': 'revenging',
#   'rank': 66812,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6686251341910455,
#   'rich_cosine': 0.46630286938910376,
#   'poor_cosine': -0.36990989178452166},
#  {'word': 'sophisms',
#   'rank': 66814,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6591460327122631,
#   'rich_cosine': 0.4521056159333196,
#   'poor_cosine': -0.38456010166639315},
#  {'word': 'reviling',
#   'rank': 66817,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6595265421842338,
#   'rich_cosine': 0.48860344157137825,
#   'poor_cosine': -0.34715320596394666},
#  {'word': 'bauble',
#   'rank': 66819,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.662611835816171,
#   'rich_cosine': 0.4683504865823863,
#   'poor_cosine': -0.37764200075919113},
#  {'word': 'impulsion',
#   'rank': 66824,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.669985782681182,
#   'rich_cosine': 0.45718879631569087,
#   'poor_cosine': -0.38491909138033115},
#  {'word': 'manoah',
#   'rank': 66831,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6520262801864051,
#   'rich_cosine': 0.49485007165928996,
#   'poor_cosine': -0.33545442271931813},
#  {'word': 'truisms',
#   'rank': 66838,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6678608719671288,
#   'rich_cosine': 0.44259311264833917,
#   'poor_cosine': -0.39409595439330486},
#  {'word': 'crestfallen',
#   'rank': 66845,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6735954577497284,
#   'rich_cosine': 0.463231151493129,
#   'poor_cosine': -0.3744638113225515},
#  {'word': 'roxy',
#   'rank': 66857,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6626090721293748,
#   'rich_cosine': 0.46381151237674567,
#   'poor_cosine': -0.3773007201175036},
#  {'word': 'brocklehurst',
#   'rank': 66871,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.673037089804382,
#   'rich_cosine': 0.46177011697149584,
#   'poor_cosine': -0.38278158111116406},
#  {'word': 'marcius',
#   'rank': 66900,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6746905102057963,
#   'rich_cosine': 0.4709894511603432,
#   'poor_cosine': -0.37062323901101474},
#  {'word': 'incontinently',
#   'rank': 66906,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.668135055967065,
#   'rich_cosine': 0.47123992622367983,
#   'poor_cosine': -0.3709765933894959},
#  {'word': 'monstrosities',
#   'rank': 66917,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6692732182255497,
#   'rich_cosine': 0.46845262594179143,
#   'poor_cosine': -0.3696221448890298},
#  {'word': 'discouragements',
#   'rank': 66962,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6711792473530507,
#   'rich_cosine': 0.4657793992128772,
#   'poor_cosine': -0.3612152808407397},
#  {'word': 'gaoler',
#   'rank': 66964,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6772842624873381,
#   'rich_cosine': 0.4692142712938924,
#   'poor_cosine': -0.3668411815137938},
#  {'word': 'unchristian',
#   'rank': 66965,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6452040226690269,
#   'rich_cosine': 0.4769275304451618,
#   'poor_cosine': -0.3553152724275213},
#  {'word': 'improvidence',
#   'rank': 66966,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6534022766923321,
#   'rich_cosine': 0.4744991721705438,
#   'poor_cosine': -0.34637741236289105},
#  {'word': 'altho',
#   'rank': 66978,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6789081318942997,
#   'rich_cosine': 0.46587547594982803,
#   'poor_cosine': -0.37279429835515804},
#  {'word': 'sharpshooters',
#   'rank': 66983,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6635873658484025,
#   'rich_cosine': 0.4618603858411983,
#   'poor_cosine': -0.3760223559353669},
#  {'word': 'remorseful',
#   'rank': 66988,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6673028471759853,
#   'rich_cosine': 0.4754582317238917,
#   'poor_cosine': -0.36536359008741326},
#  {'word': 'hisself',
#   'rank': 67010,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6802424927669919,
#   'rich_cosine': 0.4695190459623426,
#   'poor_cosine': -0.36566833455696074},
#  {'word': 'preordained',
#   'rank': 67012,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6809504612040941,
#   'rich_cosine': 0.4617541491624881,
#   'poor_cosine': -0.37305966881056196},
#  {'word': 'anthropometry',
#   'rank': 67032,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6589956288959339,
#   'rich_cosine': 0.46896931282739923,
#   'poor_cosine': -0.3552840128850494},
#  {'word': 'sunnis',
#   'rank': 67037,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6637997834453516,
#   'rich_cosine': 0.473058993325795,
#   'poor_cosine': -0.36507692182065027},
#  {'word': 'camillus',
#   'rank': 67042,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6743167883839191,
#   'rich_cosine': 0.46302306057039144,
#   'poor_cosine': -0.3768294109068387},
#  {'word': 'hereupon',
#   'rank': 67043,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6662500726764939,
#   'rich_cosine': 0.46737257598983756,
#   'poor_cosine': -0.37470072568117424},
#  {'word': 'ihe',
#   'rank': 67065,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6681257507168308,
#   'rich_cosine': 0.44320038355192964,
#   'poor_cosine': -0.38854936075510266},
#  {'word': 'evill',
#   'rank': 67073,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6768204499055652,
#   'rich_cosine': 0.47522862160772944,
#   'poor_cosine': -0.3612145670344661},
#  {'word': 'plumstead',
#   'rank': 67074,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6755887568421031,
#   'rich_cosine': 0.46781774660611786,
#   'poor_cosine': -0.3736346991782346},
#  {'word': 'crumpling',
#   'rank': 67087,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6654459811618283,
#   'rich_cosine': 0.44722610713543104,
#   'poor_cosine': -0.39139485925041373},
#  {'word': 'tactless',
#   'rank': 67095,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.667197423790015,
#   'rich_cosine': 0.4579552168584304,
#   'poor_cosine': -0.3881835069834524},
#  {'word': 'cranly',
#   'rank': 67104,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6803098159424885,
#   'rich_cosine': 0.46420264028587066,
#   'poor_cosine': -0.37365675831634565},
#  {'word': 'forhandlingar',
#   'rank': 67110,
#   'nearest_neighbor': 'geologiska',
#   'closeness': 0.6498747592037749,
#   'rich_cosine': 0.4024740824949317,
#   'poor_cosine': -0.4334139688016345},
#  {'word': 'freeholder',
#   'rank': 67117,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6297110991989566,
#   'rich_cosine': 0.4943636158519458,
#   'poor_cosine': -0.32044702852174817},
#  {'word': 'saragossa',
#   'rank': 67118,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.653887631940807,
#   'rich_cosine': 0.4559692238552373,
#   'poor_cosine': -0.38326473802983685},
#  {'word': 'clodius',
#   'rank': 67119,
#   'nearest_neighbor': 'wordes',
#   'closeness': 0.6656661873973718,
#   'rich_cosine': 0.45459263013180023,
#   'poor_cosine': -0.38782475372854247},
#  {'word': 'undistinguishable',
#   'rank': 67125,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6716034620256894,
#   'rich_cosine': 0.4610621966900316,
#   'poor_cosine': -0.37464460007398426},
#  {'word': 'heare',
#   'rank': 67130,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6654231920792884,
#   'rich_cosine': 0.47226365278094473,
#   'poor_cosine': -0.36967387642475447},
#  {'word': 'thoughtlessly',
#   'rank': 67138,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6665791065815087,
#   'rich_cosine': 0.46934122235662745,
#   'poor_cosine': -0.3727972405253663},
#  {'word': 'tabooed',
#   'rank': 67148,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6726939901998757,
#   'rich_cosine': 0.4624737884747218,
#   'poor_cosine': -0.37383262148180924},
#  {'word': 'nity',
#   'rank': 67155,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6762242859955694,
#   'rich_cosine': 0.470689894550725,
#   'poor_cosine': -0.3705851802280263},
#  {'word': 'pitieth',
#   'rank': 67181,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6529514536434482,
#   'rich_cosine': 0.49020436395524525,
#   'poor_cosine': -0.33725549832314433},
#  {'word': 'haue',
#   'rank': 67192,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6625500186781924,
#   'rich_cosine': 0.4699521129078059,
#   'poor_cosine': -0.37494580712260084},
#  {'word': 'jaunt',
#   'rank': 67196,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6767099540685535,
#   'rich_cosine': 0.4586479299535144,
#   'poor_cosine': -0.3799475334739741},
#  {'word': 'davilow',
#   'rank': 67207,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6744035499471351,
#   'rich_cosine': 0.4682812299191068,
#   'poor_cosine': -0.37398601668147047},
#  {'word': 'miserly',
#   'rank': 67268,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6753654600802215,
#   'rich_cosine': 0.4668963363225395,
#   'poor_cosine': -0.3662448894184595},
#  {'word': 'supervening',
#   'rank': 67275,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6704655340003808,
#   'rich_cosine': 0.45941661796419375,
#   'poor_cosine': -0.37636384514887145},
#  {'word': 'truncheon',
#   'rank': 67324,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6681186009011159,
#   'rich_cosine': 0.4633273965304499,
#   'poor_cosine': -0.3690604173512238},
#  {'word': 'spoiler',
#   'rank': 67325,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6688862898521316,
#   'rich_cosine': 0.4683029519071344,
#   'poor_cosine': -0.3705580979934219},
#  {'word': 'montorio',
#   'rank': 67336,
#   'nearest_neighbor': 'vincoli',
#   'closeness': 0.6784917719491492,
#   'rich_cosine': 0.4420551782808962,
#   'poor_cosine': -0.4142708377590809},
#  {'word': 'gallants',
#   'rank': 67393,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.66528664860669,
#   'rich_cosine': 0.4641084194223655,
#   'poor_cosine': -0.37631136253863184},
#  {'word': 'sentience',
#   'rank': 67447,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6741971580848998,
#   'rich_cosine': 0.4689784224364002,
#   'poor_cosine': -0.3706159242611499},
#  {'word': 'bucklaw',
#   'rank': 67461,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6792194297798791,
#   'rich_cosine': 0.4656638069240474,
#   'poor_cosine': -0.37266292006178947},
#  {'word': 'expertness',
#   'rank': 67477,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6681132205362164,
#   'rich_cosine': 0.46175233107968244,
#   'poor_cosine': -0.3633281823531944},
#  {'word': 'devoir',
#   'rank': 67480,
#   'nearest_neighbor': 'miroir',
#   'closeness': 0.6709384825890343,
#   'rich_cosine': 0.394749924860227,
#   'poor_cosine': -0.4535979558891142},
#  {'word': 'drearily',
#   'rank': 67482,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6781495820531273,
#   'rich_cosine': 0.46188383668794286,
#   'poor_cosine': -0.37119612331770674},
#  {'word': 'rebounded',
#   'rank': 67494,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6698847892775993,
#   'rich_cosine': 0.4729810595211215,
#   'poor_cosine': -0.37056142051007956},
#  {'word': 'opportunists',
#   'rank': 67495,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6784206972728719,
#   'rich_cosine': 0.4711525780824292,
#   'poor_cosine': -0.36517358074866557},
#  {'word': 'dreamlike',
# ...
#  {'word': '1967a',
#   'rank': 70298,
#   'nearest_neighbor': '1968a',
#   'closeness': 0.6519636116571159,
#   'rich_cosine': 0.4248858786487561,
#   'poor_cosine': -0.4097233162252318},
#  {'word': 'chantry',
#   'rank': 70321,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.663015648478824,
#   'rich_cosine': 0.45281305339017336,
#   'poor_cosine': -0.38398831313830134},
#  {'word': 'cicerone',
#   'rank': 70322,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6667585777584374,
#   'rich_cosine': 0.4555869132184716,
#   'poor_cosine': -0.39382015267889187},
#  {'word': 'contritely',
#   'rank': 70344,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6720446822699325,
#   'rich_cosine': 0.4733293690643356,
#   'poor_cosine': -0.3660936071142683},
#  {'word': 'lxii',
#   'rank': 70348,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6550129016820083,
#   'rich_cosine': 0.44061505698006564,
#   'poor_cosine': -0.3976894900626031},
#  {'word': 'blackmur',
#   'rank': 70352,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6660831574667474,
#   'rich_cosine': 0.4651279072575753,
#   'poor_cosine': -0.3796498026970991},
#  {'word': 'lxi',
#   'rank': 70378,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6677755026767648,
#   'rich_cosine': 0.4363430874031442,
#   'poor_cosine': -0.39966567059534935},
#  {'word': 'pasley',
#   'rank': 70433,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6629486241013304,
#   'rich_cosine': 0.4553843279943307,
#   'poor_cosine': -0.37777462090388725},
#  {'word': 'rymer',
#   'rank': 70486,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6667028304926057,
#   'rich_cosine': 0.4491504057094475,
#   'poor_cosine': -0.3969520290846225},
#  {'word': 'illingworth',
#   'rank': 70490,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6664231078756544,
#   'rich_cosine': 0.46488275613477076,
#   'poor_cosine': -0.37540635099973557},
#  {'word': 'atchley',
#   'rank': 70538,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6679584773386426,
#   'rich_cosine': 0.4550490050393076,
#   'poor_cosine': -0.395026324119723},
#  {'word': 'greenacre',
#   'rank': 70541,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.658411135434961,
#   'rich_cosine': 0.43354239602794925,
#   'poor_cosine': -0.4034069916304234},
#  {'word': 'lviii',
#   'rank': 70543,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6684529324188614,
#   'rich_cosine': 0.43407629567006173,
#   'poor_cosine': -0.41082111821459555},
#  {'word': 'winick',
#   'rank': 70576,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6807911149590917,
#   'rich_cosine': 0.4490459574746474,
#   'poor_cosine': -0.391137879357177},
#  {'word': 'scheff',
#   'rank': 70579,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6269082466287833,
#   'rich_cosine': 0.43908846352063774,
#   'poor_cosine': -0.3698330625766146},
#  {'word': 'diebold',
#   'rank': 70580,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6620651556846504,
#   'rich_cosine': 0.4555573725844871,
#   'poor_cosine': -0.3878850484243518},
#  {'word': 'carstairs',
#   'rank': 70599,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6690050432832214,
#   'rich_cosine': 0.45195631783894213,
#   'poor_cosine': -0.38742513141032753},
#  {'word': 'mcginty',
#   'rank': 70608,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6659643106531831,
#   'rich_cosine': 0.45269908924577557,
#   'poor_cosine': -0.3936081188601903},
#  {'word': 'higgledy',
#   'rank': 70620,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6647495305173224,
#   'rich_cosine': 0.48035133896000476,
#   'poor_cosine': -0.3675037532176843},
#  {'word': 'sarbin',
#   'rank': 70625,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6639149577704209,
#   'rich_cosine': 0.42417669976361116,
#   'poor_cosine': -0.4145937482420644},
#  {'word': 'nebbia',
#   'rank': 70627,
#   'nearest_neighbor': 'nosegay',
#   'closeness': 0.6650822768099636,
#   'rich_cosine': 0.46214999922278677,
#   'poor_cosine': -0.37641523052522274},
#  {'word': 'plott',
#   'rank': 70638,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6691423045032457,
#   'rich_cosine': 0.46121868486215223,
#   'poor_cosine': -0.3869680139220812},
#  {'word': 'callender',
#   'rank': 70643,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.685555684110024,
#   'rich_cosine': 0.44802070676213446,
#   'poor_cosine': -0.39614717731070087},
#  {'word': 'mishan',
#   'rank': 70679,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6583946450470749,
#   'rich_cosine': 0.4591829074080603,
#   'poor_cosine': -0.36822117901373824},
#  {'word': 'fagot',
#   'rank': 70704,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6792045024978309,
#   'rich_cosine': 0.46338499816011935,
#   'poor_cosine': -0.3804771699123162},
#  {'word': 'horrocks',
#   'rank': 70708,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6794256443422365,
#   'rich_cosine': 0.4558337329085103,
#   'poor_cosine': -0.3826112885991567},
#  {'word': 'liii',
#   'rank': 70721,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6742260479594285,
#   'rich_cosine': 0.43948901421407394,
#   'poor_cosine': -0.40234360861522966},
#  {'word': 'rithmetic',
#   'rank': 70745,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6633963826594417,
#   'rich_cosine': 0.4505159105552422,
#   'poor_cosine': -0.38348759773594093},
#  {'word': 'wilamowitz',
#   'rank': 70746,
#   'nearest_neighbor': 'moellendorff',
#   'closeness': 0.6764257561645977,
#   'rich_cosine': 0.4454805643144971,
#   'poor_cosine': -0.41056537896634865},
#  {'word': 'goodsell',
#   'rank': 70756,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6701752996514654,
#   'rich_cosine': 0.4610468091180084,
#   'poor_cosine': -0.3837657621090499},
#  {'word': 'ual',
#   'rank': 70762,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6762908623866289,
#   'rich_cosine': 0.4625538100627036,
#   'poor_cosine': -0.3781655407975102},
#  {'word': 'lxiii',
#   'rank': 70763,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6652494880500783,
#   'rich_cosine': 0.45196742791594907,
#   'poor_cosine': -0.3863834973095843},
#  {'word': 'boase',
#   'rank': 70768,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6692211578199679,
#   'rich_cosine': 0.4607117658654888,
#   'poor_cosine': -0.3854828140390998},
#  {'word': 'ulf',
#   'rank': 70799,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6708367549464305,
#   'rich_cosine': 0.4602395068045508,
#   'poor_cosine': -0.3764964004573634},
#  {'word': 'moyle',
#   'rank': 70803,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6742901510765931,
#   'rich_cosine': 0.45535526138450844,
#   'poor_cosine': -0.3841289742212754},
#  {'word': 'varley',
#   'rank': 70809,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6720799990033243,
#   'rich_cosine': 0.4598558964313755,
#   'poor_cosine': -0.38310600062117},
#  {'word': 'hagg',
#   'rank': 70829,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6675120173563124,
#   'rich_cosine': 0.4631052048984757,
#   'poor_cosine': -0.37795817460559156},
#  {'word': 'swank',
#   'rank': 70832,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6749915363446686,
#   'rich_cosine': 0.4616994270169135,
#   'poor_cosine': -0.38925019270467287},
#  {'word': 'hirth',
#   'rank': 70843,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6736842474370872,
#   'rich_cosine': 0.4311231700106646,
#   'poor_cosine': -0.41507396925455115},
#  {'word': 'sitaram',
#   'rank': 70845,
#   'nearest_neighbor': 'arunachalam',
#   'closeness': 0.6250734905534397,
#   'rich_cosine': 0.4566790108886811,
#   'poor_cosine': -0.3575362772176053},
#  {'word': 'lounsbury',
#   'rank': 70851,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6766343942904512,
#   'rich_cosine': 0.44076965299947396,
#   'poor_cosine': -0.4030577430774249},
#  {'word': 'haggett',
#   'rank': 70860,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6570750709297222,
#   'rich_cosine': 0.4339681853196483,
#   'poor_cosine': -0.40088502604727233},
#  {'word': 'aspinwall',
#   'rank': 70878,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6751559539679746,
#   'rich_cosine': 0.45122735936478364,
#   'poor_cosine': -0.3882353391254005},
#  {'word': 'shahr',
#   'rank': 70907,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6758012229875393,
#   'rich_cosine': 0.46984502416249607,
#   'poor_cosine': -0.3675853668056313},
#  {'word': 'murrell',
#   'rank': 70915,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.665635395506651,
#   'rich_cosine': 0.45086634310612994,
#   'poor_cosine': -0.3958714518849163},
#  {'word': 'rustam',
#   'rank': 70918,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.67873285829443,
#   'rich_cosine': 0.4629715970167396,
#   'poor_cosine': -0.37631140067561647},
#  {'word': '1966a',
#   'rank': 70920,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6502003521211239,
#   'rich_cosine': 0.43890457543012334,
#   'poor_cosine': -0.3956280880242479},
#  {'word': 'macnamara',
#   'rank': 70953,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6703067260477147,
#   'rich_cosine': 0.4374512930912896,
#   'poor_cosine': -0.40408822618910833},
#  {'word': 'kepner',
#   'rank': 70954,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6818741498281614,
#   'rich_cosine': 0.45121523592815943,
#   'poor_cosine': -0.3874235649640106},
#  {'word': 'wilkin',
#   'rank': 70963,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6779191439762285,
#   'rich_cosine': 0.4575157076325626,
#   'poor_cosine': -0.3875799724638389},
#  {'word': 'nagle',
#   'rank': 70964,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.666086364680988,
#   'rich_cosine': 0.45189062087167503,
#   'poor_cosine': -0.3955714265710737},
#  {'word': 'korner',
#   'rank': 70970,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.670070093960603,
#   'rich_cosine': 0.44312749275586755,
#   'poor_cosine': -0.39966365013046584},
#  {'word': 'ensor',
#   'rank': 70982,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6713637563529925,
#   'rich_cosine': 0.45461384986066494,
#   'poor_cosine': -0.3828447765969843},
#  {'word': 'emerton',
#   'rank': 70983,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6676952377103591,
#   'rich_cosine': 0.4620154902644642,
#   'poor_cosine': -0.3819425385515589},
#  {'word': 'titchener',
#   'rank': 70994,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6734928563793809,
#   'rich_cosine': 0.44524926776778107,
#   'poor_cosine': -0.39532643272287055},
#  {'word': 'hinkle',
#   'rank': 70997,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6780262001688216,
#   'rich_cosine': 0.4616565134268227,
#   'poor_cosine': -0.3808055961754933},
#  {'word': 'graden',
#   'rank': 71013,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6709634007159481,
#   'rich_cosine': 0.4588744998505232,
#   'poor_cosine': -0.3828303186507806},
#  {'word': 'nauta',
#   'rank': 71014,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6666494023393071,
#   'rich_cosine': 0.45222602932104705,
#   'poor_cosine': -0.3926031943277542},
#  {'word': 'sokolov',
#   'rank': 71015,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6684333677570949,
#   'rich_cosine': 0.43568871707776136,
#   'poor_cosine': -0.40249474993993},
#  {'word': 'miall',
#   'rank': 71019,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6759556855326101,
#   'rich_cosine': 0.4399442563740718,
#   'poor_cosine': -0.4054010093730479},
#  {'word': 'birge',
#   'rank': 71022,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6649143213726704,
#   'rich_cosine': 0.44308039204318794,
#   'poor_cosine': -0.4017881458337146},
#  {'word': 'suomi',
#   'rank': 71025,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6717097453753059,
#   'rich_cosine': 0.4584119975350471,
#   'poor_cosine': -0.3751865858762047},
#  {'word': 'wolstenholme',
#   'rank': 71036,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.655411541175091,
#   'rich_cosine': 0.47712729280253874,
#   'poor_cosine': -0.361314604662518},
#  {'word': 'readin',
#   'rank': 71039,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6753742642269772,
#   'rich_cosine': 0.4698237783618864,
#   'poor_cosine': -0.3719394122167713},
#  {'word': '1962a',
#   'rank': 71043,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6626544964149584,
#   'rich_cosine': 0.4323860952766668,
#   'poor_cosine': -0.39947077252847907},
#  {'word': 'gast',
#   'rank': 71046,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6618931473309768,
#   'rich_cosine': 0.4520589236012427,
#   'poor_cosine': -0.3912079990241134},
#  {'word': 'windle',
#   'rank': 71048,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6700231748280312,
#   'rich_cosine': 0.46689666841997374,
#   'poor_cosine': -0.3779132880217829},
#  {'word': 'huebner',
#   'rank': 71049,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6697214344071615,
#   'rich_cosine': 0.4604049570183518,
#   'poor_cosine': -0.3868109760180248},
#  {'word': 'kounin',
#   'rank': 71051,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.661824944176223,
#   'rich_cosine': 0.4494516643367827,
#   'poor_cosine': -0.3875819777876141},
#  {'word': 'krumboltz',
#   'rank': 71055,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6741356645854563,
#   'rich_cosine': 0.44827407469267566,
#   'poor_cosine': -0.3905303425127031},
#  {'word': 'mccrady',
#   'rank': 71057,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6778610049194601,
#   'rich_cosine': 0.468346528869639,
#   'poor_cosine': -0.3689138816489682},
#  {'word': 'racker',
#   'rank': 71058,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6563850591976235,
#   'rich_cosine': 0.42236934700430884,
#   'poor_cosine': -0.4054168738273898},
#  {'word': 'furnas',
#   'rank': 71066,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6618550878364152,
#   'rich_cosine': 0.4561838280455286,
#   'poor_cosine': -0.3856318670164997},
#  {'word': 'farran',
#   'rank': 71067,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6573330485760077,
#   'rich_cosine': 0.46164326647351694,
#   'poor_cosine': -0.3783346893412854},
#  {'word': 'gilliland',
#   'rank': 71069,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6728635567503168,
#   'rich_cosine': 0.4526087448696524,
#   'poor_cosine': -0.39157861363291335},
#  {'word': 'shantz',
#   'rank': 71070,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.669941867220612,
#   'rich_cosine': 0.4525916432356061,
#   'poor_cosine': -0.3947318128853753},
#  {'word': 'goslin',
#   'rank': 71077,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6805856691937957,
#   'rich_cosine': 0.4514835537164856,
#   'poor_cosine': -0.38450512661860337},
#  {'word': 'ruddle',
#   'rank': 71079,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6762151125941043,
#   'rich_cosine': 0.45414972237180623,
#   'poor_cosine': -0.38959016453140055},
#  {'word': 'wever',
#   'rank': 71083,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6744394756206861,
#   'rich_cosine': 0.44969549952462873,
#   'poor_cosine': -0.39203033280861127},
#  {'word': 'ebel',
#   'rank': 71084,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6804329005543007,
#   'rich_cosine': 0.45696936695075735,
#   'poor_cosine': -0.38363644622863613},
#  {'word': 'hollingworth',
#   'rank': 71085,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6617482896130734,
#   'rich_cosine': 0.4295036940550862,
#   'poor_cosine': -0.40950595240352994},
#  {'word': 'bellak',
#   'rank': 71086,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6669588706387742,
#   'rich_cosine': 0.45344780503270643,
#   'poor_cosine': -0.38420321869344765},
#  {'word': 'myklebust',
#   'rank': 71089,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6630784650093554,
#   'rich_cosine': 0.4270744725562805,
#   'poor_cosine': -0.40487097258736887},
#  {'word': 'koshland',
#   'rank': 71090,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6636261160408162,
#   'rich_cosine': 0.4562071165874355,
#   'poor_cosine': -0.38502296314223716},
#  {'word': 'ahrens',
#   'rank': 71091,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6681861822155807,
#   'rich_cosine': 0.46557422576579216,
#   'poor_cosine': -0.3791450109518337},
#  {'word': 'proshansky',
#   'rank': 71092,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6752815431605781,
#   'rich_cosine': 0.4478934483641802,
#   'poor_cosine': -0.39785031231302287},
#  {'word': 'thyer',
#   'rank': 71095,
#   'nearest_neighbor': 'assembles',
#   'closeness': 0.6659995243983966,
#   'rich_cosine': 0.45854795424774414,
#   'poor_cosine': -0.3842683692825489},
#  {'word': 'passow',
#   'rank': 71096,
#   'nearest_neighbor': 'merwin',
#   'closeness': 0.6669394794397144,
#   'rich_cosine': 0.4593690859499968,
#   'poor_cosine': -0.3802615999463474}]

# %%
import json
with open("1990-rich-poor.json", 'w') as f:
    json.dump(df_dicts, f)
